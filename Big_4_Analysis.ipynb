# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1.	Load the datase
df = pd.read_csv("big4_financial_risk_compliance.csv")

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score'],
#       dtype='object')

# %%
# 2.	Display the first 10 records. 
df.head(10)
# Out:
#    Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0  2020            PwC                     2829               51
# 1  2022       Deloitte                     3589              185
# 2  2020            PwC                     2438              212
# 3  2021            PwC                     2646              397
# 4  2020            PwC                     2680              216
# 5  2023       Deloitte                      818              448
# 6  2022       Deloitte                     1199              148
# 7  2020            PwC                     4092              500
# 8  2021            PwC                     4156              362
# 9  2021  Ernst & Young                     2490               74
#
#    Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                    123                    39        Healthcare
# 1                     30                    60        Healthcare
# ...

# %%
df.describe()
# Out:
#               Year  Total_Audit_Engagements  High_Risk_Cases  \
# count   100.000000               100.000000       100.000000
# mean   2022.320000              2784.520000       277.730000
# std       1.780251              1281.863073       135.735174
# min    2020.000000               603.000000        51.000000
# 25%    2021.000000              1768.250000       162.500000
# 50%    2022.000000              2650.000000       293.000000
# 75%    2024.000000              4008.750000       395.500000
# max    2025.000000              4946.000000       500.000000
#
#        Compliance_Violations  Fraud_Cases_Detected  Total_Revenue_Impact  \
# count             100.000000            100.000000            100.000000
# mean              105.480000             52.700000            272.539000
# std                55.370101             28.311221            139.151401
# min                10.000000              5.000000             33.460000
# ...

# %%
# 3.	Display last 10 records. 
df.tail(10)
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 90  2020       Deloitte                     1925              189
# 91  2023           KPMG                     2919              453
# 92  2022            PwC                     4595              481
# 93  2021       Deloitte                      797              133
# 94  2023  Ernst & Young                     4895              123
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 90                     39                    52              Tech
# 91                     35                    99              Tech
# ...

# %%
# 4.	Display 5 random records. 
df.sample(5)
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 4   2020            PwC                     2680              216
# 17  2022       Deloitte                     4813              249
# 76  2020  Ernst & Young                     1286              391
# 8   2021            PwC                     4156              362
# 20  2024       Deloitte                     1581              247
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 4                      99                    46        Healthcare
# 17                     81                    64            Retail
# 76                     47                    60              Tech
# 8                      53                    95           Finance
# 20                    181                    72            Retail
#
#     Total_Revenue_Impact AI_Used_for_Auditing  Employee_Workload  \
# 4                  48.00                   No                 51
# ...

# %%
# 5.	Check data types of all columns. 
df.dtypes
# Out:
# Year                           int64
# Firm_Name                     object
# Total_Audit_Engagements        int64
# High_Risk_Cases                int64
# Compliance_Violations          int64
# Fraud_Cases_Detected           int64
# Industry_Affected             object
# Total_Revenue_Impact         float64
# AI_Used_for_Auditing          object
# Employee_Workload              int64
# Audit_Effectiveness_Score    float64
# Client_Satisfaction_Score    float64
# dtype: object

# %%
# 6.	Find total rows and columns. 
print(df.shape)
# Out:
# (100, 12)

# %%
# 7.	Check for missing values. 
print(df.isnull().sum())
# Out:
# Year                         0
# Firm_Name                    0
# Total_Audit_Engagements      0
# High_Risk_Cases              0
# Compliance_Violations        0
# Fraud_Cases_Detected         0
# Industry_Affected            0
# Total_Revenue_Impact         0
# AI_Used_for_Auditing         0
# Employee_Workload            0
# Audit_Effectiveness_Score    0
# Client_Satisfaction_Score    0
# dtype: int64

# %%
# 8.	Check for duplicate records. 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score'],
#       dtype='object')

# %%
# Part 2: New Column Creation
# 1.	Create Revenue Impact (Millions) by converting Total Revenue Impact into millions.
df["Revenue Impact (Millions)"] = df["Total_Revenue_Impact"]/1000000
df
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
df
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
# 2.	Create Risk Ratio = High Risk Cases / Total Audit Engagements. 
# Calculate the Risk Ratio
df['Risk Ratio'] = df['High_Risk_Cases'] / df['Total_Audit_Engagements']

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio'],
#       dtype='object')

# %%
# 3.	Create Compliance Rate = (Total Audit Engagements − Compliance Violations) / Total Audit Engagements. 
df["Compliance_Rate"] = ((df["Total_Audit_Engagements"]-df["Compliance_Violations"])/df["Total_Audit_Engagements"])

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate'],
#       dtype='object')

# %%
# 4.	Create Fraud Detection Rate = Fraud Cases Detected / High Risk Cases. 
df["Fraud_Detection_Rate"] = df["Fraud_Cases_Detected"]/df["High_Risk_Cases"]

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Audit_Effectiveness_Score"].sum()
# Out:
# np.float64(748.9999999999999)

# %%
df["Audit_Effectiveness_Score"].min()
# Out:
# 5.0

# %%
df["Audit_Effectiveness_Score"].median()
# Out:
# 7.45

# %%
df["Audit_Effectiveness_Score"].max()
# Out:
# 10.0

# %%
# 5.	Categorize Audit Effectiveness Score into: 
# o	Low 
# o	Medium 
# o	High 
df["Audit_Effectiveness_Score"].min(),
df["Audit_Effectiveness_Score"].median(),
df["Audit_Effectiveness_Score"].max(),
df.sort_values
# Out:
# <bound method DataFrame.sort_values of     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Part 3: Filtering Analysis
# 1.	Find all records of Deloitte. 
df["Firm_Name"].unique(),
# Out:
# (array(['PwC', 'Deloitte', 'Ernst & Young', 'KPMG'], dtype=object),)

# %%
(df[df["Firm_Name"]=='Deloitte'])
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 1   2022  Deloitte                     3589              185
# 5   2023  Deloitte                      818              448
# 6   2022  Deloitte                     1199              148
# 12  2024  Deloitte                     2885              469
# 15  2021  Deloitte                     3490              127
# 17  2022  Deloitte                     4813              249
# 18  2022  Deloitte                     2804              273
# 20  2024  Deloitte                     1581              247
# 21  2025  Deloitte                      760              406
# 30  2020  Deloitte                     2030              200
# 34  2022  Deloitte                     4287              158
# 37  2024  Deloitte                     4324              483
# 39  2021  Deloitte                      603               62
# 46  2025  Deloitte                      718              360
# ...

# %%
df["AI_Used_for_Auditing"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# 2.	Find all records where AI was used for auditing. 
(df[df["AI_Used_for_Auditing"]=='Yes'])
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 1   2022       Deloitte                     3589              185
# 7   2020            PwC                     4092              500
# 9   2021  Ernst & Young                     2490               74
# 10  2020           KPMG                     1497              330
# 11  2024  Ernst & Young                     2712              408
# 13  2023            PwC                     2267              164
# 14  2020            PwC                     2333              358
# 15  2021       Deloitte                     3490              127
# 16  2020  Ernst & Young                     3264              435
# 19  2021           KPMG                     2239               78
# 21  2025       Deloitte                      760              406
# 22  2023            PwC                     2238              101
# 23  2024  Ernst & Young                     1760              415
# ...

# %%
(df[df["AI_Used_for_Auditing"]=='Yes']).shape[0]
# Out:
# 45

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Audit_Effectiveness_Score"].unique()
# Out:
# array([ 5.8,  5.3,  6.1,  5.1,  9.1,  9.6,  9.4,  6. ,  6.8,  8.3,  9.5,
#         9.3,  7.3, 10. ,  8.4,  9.8,  6.6,  8. ,  5.6,  7. ,  8.2,  6.7,
#         6.2,  7.4,  5.2,  7.2,  6.9,  8.9,  9.2,  8.8,  7.7,  5.5,  9.9,
#         7.6,  7.5,  7.8,  8.5,  5. ,  5.9,  9. ,  6.5,  7.9,  8.6,  5.4,
#         6.3,  6.4,  8.7])

# %%
# 3.	Find firms with Audit Effectiveness Score greater than 8. 
(df[df["Audit_Effectiveness_Score"]>8])
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 4   2020            PwC                     2680              216
# 6   2022       Deloitte                     1199              148
# 7   2020            PwC                     4092              500
# 10  2020           KPMG                     1497              330
# 11  2024  Ernst & Young                     2712              408
# 12  2024       Deloitte                     2885              469
# 14  2020            PwC                     2333              358
# 15  2021       Deloitte                     3490              127
# 17  2022       Deloitte                     4813              249
# 23  2024  Ernst & Young                     1760              415
# 28  2025  Ernst & Young                     4773              497
# 33  2024  Ernst & Young                     4481              258
# 34  2022       Deloitte                     4287              158
# ...

# %%
df["Compliance_Violations"].unique()
# Out:
# array([123,  30, 124,  55,  99,  10, 114, 152,  53, 144, 186, 125,  48,
#         17,  82,  81,  87, 181,  65, 184, 183, 179,  49, 146, 169,  94,
#        136,  73,  37,  61, 166,  42, 100, 134, 138, 115, 116, 155, 193,
#        196, 139,  86, 137, 126, 149,  74,  45, 167,  20,  92, 185, 151,
#        198, 141,  25, 142,  31, 102, 103,  15,  71,  38,  58,  47,  19,
#         67, 132, 200, 121,  90, 158,  36,  39,  35, 173,  46, 153, 199])

# %%
# 4.	Find records where Compliance Violations exceed 50.
(df[df["Compliance_Violations"]>50])
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# 6   2022       Deloitte                     1199              148
# ..   ...            ...                      ...              ...
# 94  2023  Ernst & Young                     4895              123
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Industry_Affected"].unique()
# Out:
# array(['Healthcare', 'Finance', 'Retail', 'Tech'], dtype=object)

# %%
# 5.	Find Financial Services industry records. 
(df[df["Industry_Affected"]=='Finance'])
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 5   2023       Deloitte                      818              448
# 8   2021            PwC                     4156              362
# 10  2020           KPMG                     1497              330
# 15  2021       Deloitte                     3490              127
# 21  2025       Deloitte                      760              406
# 28  2025  Ernst & Young                     4773              497
# 36  2023            PwC                     3449              102
# 48  2025            PwC                     4775              380
# 50  2021           KPMG                     4327              312
# 56  2024  Ernst & Young                     2556              306
# 58  2020            PwC                     4401              249
# 65  2024       Deloitte                     2183              449
# 67  2022           KPMG                     4624              472
# ...

# %%
df["AI_Used_for_Auditing"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# 6.	Find Healthcare industry records with AI used. 
df[(df["Industry_Affected"]=='Healthcare')&(df["AI_Used_for_Auditing"]=='Yes')]
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 1   2022       Deloitte                     3589              185
# 11  2024  Ernst & Young                     2712              408
# 23  2024  Ernst & Young                     1760              415
# 24  2024            PwC                     4103              423
# 31  2020  Ernst & Young                      811              398
# 44  2022  Ernst & Young                     1578              122
# 55  2025           KPMG                     2506              330
# 70  2023            PwC                     2283               58
# 95  2022           KPMG                     4179               77
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 1                      30                    60        Healthcare
# 11                    186                    61        Healthcare
# 23                    183                    11        Healthcare
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Client_Satisfaction_Score"].unique()
# Out:
# array([ 8.4,  6.7,  6.2,  8.6,  7.1,  6.3,  9.5,  6. ,  7.3,  8. ,  8.9,
#         7.7,  8.3,  7.5,  7.6,  7.9,  5. ,  5.6,  6.1,  9.3,  9.6,  8.8,
#         5.1,  6.5,  9.2,  5.5,  8.5,  6.4,  5.2,  5.7,  5.8,  9.9,  7.8,
#         5.4,  7. ,  6.9,  6.6, 10. ,  9. ,  7.4,  5.9,  5.3,  9.1,  8.7])

# %%
# 7.	Find records where Client Satisfaction Score is above 8. 
(df[df["Client_Satisfaction_Score"]>8])
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 3   2021            PwC                     2646              397
# 7   2020            PwC                     4092              500
# 11  2024  Ernst & Young                     2712              408
# 14  2020            PwC                     2333              358
# 18  2022       Deloitte                     2804              273
# 23  2024  Ernst & Young                     1760              415
# 30  2020       Deloitte                     2030              200
# 31  2020  Ernst & Young                      811              398
# 32  2023  Ernst & Young                     1727               59
# 35  2021           KPMG                     3560              302
# 36  2023            PwC                     3449              102
# 39  2021       Deloitte                      603               62
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Fraud_Cases_Detected"].unique()
# Out:
# array([ 39,  60,  97,  46,  30,  11,  69,  95,  22,  10,  61,  92,  42,
#         17,  62,  18,  64,  36,  14,  72,  79,  54,  94,  12,  56,  90,
#         20,  32,  66,  26,  13,  63,  40,  48,   6,  28,  87,  70,  86,
#         25,  93,  91,  51,  45, 100,  24,  73,  50,  27,  33,  80,  82,
#         71,  67,   5,  81,  37,  35,  21,  52,  99,  59,  96,  58])

# %%
# 8.	Find records where Fraud Cases Detected are greater than 30. 
df[df["Fraud_Cases_Detected"]>30]
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 92  2022            PwC                     4595              481
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 9.	Find PwC records having an Audit Effectiveness Score above 8. 
df[(df["Firm_Name"]=='PwC')&(df["Audit_Effectiveness_Score"]>8)]
# Out:
#     Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 4   2020       PwC                     2680              216
# 7   2020       PwC                     4092              500
# 14  2020       PwC                     2333              358
# 48  2025       PwC                     4775              380
# 58  2020       PwC                     4401              249
# 77  2024       PwC                     1574              391
# 87  2025       PwC                     1771              158
# 88  2024       PwC                     2676              176
# 92  2022       PwC                     4595              481
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 4                      99                    46        Healthcare
# 7                     152                    69              Tech
# 14                     48                    17            Retail
# 48                    139                    87           Finance
# ...

# %%
df
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
df["Firm_Name"].unique()
# Out:
# array(['PwC', 'Deloitte', 'Ernst & Young', 'KPMG'], dtype=object)

# %%
# 10.	Find EY records with Compliance Violations below 20. 
df[(df["Firm_Name"]=='Ernst & Young')&(df["Compliance_Violations"]<20)]
# Out:
# Empty DataFrame
# Columns: [Year, Firm_Name, Total_Audit_Engagements, High_Risk_Cases, Compliance_Violations, Fraud_Cases_Detected, Industry_Affected, Total_Revenue_Impact, AI_Used_for_Auditing, Employee_Workload, Audit_Effectiveness_Score, Client_Satisfaction_Score, Revenue Impact (Millions), Risk Ratio, Compliance_Rate, Fraud_Detection_Rate]
# Index: []

# %%
# Part 4: Business KPIs
# 1.	Total Audit Engagements. 
total_audit_engagements = df["Total_Audit_Engagements"].sum()
print(total_audit_engagements)
# Out:
# 278452

# %%
print(df["Total_Audit_Engagements"].sum())
# Out:
# 278452

# %%
# 2.	Total High-Risk Cases
print(df["High_Risk_Cases"].sum())
# Out:
# 27773

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 3.	Total Compliance Violations. 
print(df["Compliance_Violations"].sum())
# Out:
# 10548

# %%
# 4.	Total Fraud Cases Detected.
print(df["Fraud_Cases_Detected"].sum())
# Out:
# 5270

# %%
# 5.	Total Revenue Impact. 
print(df["Total_Revenue_Impact"].sum())
# Out:
# 27253.9

# %%
# 6.	Average Employee Workload. 
print(df["Employee_Workload"].mean())
# Out:
# 60.25

# %%
# 7.	Average Audit Effectiveness Score. 
print(df["Audit_Effectiveness_Score"].mean())
# Out:
# 7.489999999999998

# %%
# 8.	Average Client Satisfaction Score. 
print(df["Client_Satisfaction_Score"].mean())
# Out:
# 7.338999999999999

# %%
# 9.	Total Number of Firms. 
Firm = df["Firm_Name"].nunique()
print("The number of firms are:",Firm)
# Out:
# The number of firms are: 4

# %%
# 10.	Total Number of Industries
Industry = df["Industry_Affected"].nunique()
print("The number of industries:",Industry)
# Out:
# The number of industries: 4

# %%
df["Industry_Affected"].unique()
# Out:
# array(['Healthcare', 'Finance', 'Retail', 'Tech'], dtype=object)

# %%
df
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Firm_Name"].unique()
# Out:
# array(['PwC', 'Deloitte', 'Ernst & Young', 'KPMG'], dtype=object)

# %%
df["Total_Audit_Engagements"].unique()
# Out:
# array([2829, 3589, 2438, 2646, 2680,  818, 1199, 4092, 4156, 2490, 1497,
#        2712, 2885, 2267, 2333, 3490, 3264, 4813, 2804, 2239, 1581,  760,
#        2238, 1760, 4103, 4470, 2515, 3852, 4773, 3571, 2030,  811, 1727,
#        4481, 4287, 3560, 3449, 4324, 2245,  603, 3981, 1119, 3076, 3958,
#        1578, 4570,  718, 4601, 4775, 4340, 4327, 1695,  995, 3101, 1992,
#        2506, 2556, 4390, 4401, 1275, 3630, 2654, 1810, 2208, 2133, 2183,
#        1924, 4624, 1825, 1069, 2283, 4784, 2861, 3616, 4452, 1078, 1286,
#        1574, 1076, 3305,  912, 1516, 1012, 3230, 2503, 4946, 4606, 1771,
#        2676,  962, 1925, 2919, 4595,  797, 4895, 4179, 2119, 3810, 1896,
#        4473])

# %%
# Part 5: Firm Analysis
# 1.	Total Audit Engagements by Firm. 
Firm = (
    df["Firm_Name"]
    .value_counts()
    .reset_index()
       )
Firm.columns =[
    "Firm_Name",
    "Total_Audit_Engagements"
]
print("\nThe total audit engagements is :",Firm)
# Out:
# The total audit engagements is :        Firm_Name  Total_Audit_Engagements
# 0       Deloitte                       30
# 1            PwC                       25
# 2  Ernst & Young                       23
# 3           KPMG                       22

# %%
# 2.	Total Revenue Impact by Firm
Revenue =(
    df["Firm_Name"]
        .value_counts()
        .reset_index()
)
Revenue.columns = [
    "Firm_Name",
    "Total_Revenue_Impact"
]
print("\nThe Total revenue impact by firm:")
print(Revenue)
# Out:
# The Total revenue impact by firm:
#        Firm_Name  Total_Revenue_Impact
# 0       Deloitte                    30
# 1            PwC                    25
# 2  Ernst & Young                    23
# 3           KPMG                    22

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 3.	Average Audit Effectiveness Score by Firm. 
Score = (
    df["Firm_Name"]
    .value_counts()
    .reset_index()
)
Score.columns = [
    "Firm_Name",
     "Audit_Effectiveness_Score"
]
print(" The Audit Effectiveness Score by each firm :\n",Score)
average_score = Score["Audit_Effectiveness_Score"].mean()
print(f"\nThe Average Audit Effectiveness Score across all firms is: {average_score:.2f}")
# Out:
#  The Audit Effectiveness Score by each firm :
#         Firm_Name  Audit_Effectiveness_Score
# 0       Deloitte                         30
# 1            PwC                         25
# 2  Ernst & Young                         23
# 3           KPMG                         22
#
# The Average Audit Effectiveness Score across all firms is: 25.00

# %%
df["Audit_Effectiveness_Score"].unique()
# Out:
# array([ 5.8,  5.3,  6.1,  5.1,  9.1,  9.6,  9.4,  6. ,  6.8,  8.3,  9.5,
#         9.3,  7.3, 10. ,  8.4,  9.8,  6.6,  8. ,  5.6,  7. ,  8.2,  6.7,
#         6.2,  7.4,  5.2,  7.2,  6.9,  8.9,  9.2,  8.8,  7.7,  5.5,  9.9,
#         7.6,  7.5,  7.8,  8.5,  5. ,  5.9,  9. ,  6.5,  7.9,  8.6,  5.4,
#         6.3,  6.4,  8.7])

# %%
average_score = Score["Audit_Effectiveness_Score"].mean()
print( average_score)
# Out:
# 25.0

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 4.	Average Client Satisfaction Score by Firm. 
Clint = (
    df[
        "Firm_Name"
        ]
        .value_counts()
        .reset_index()
)
Clint.columns = [
    "Firm_Name",
    "Client_Satisfaction_Score"
]
print(
    "The client satisfaction score:\n",
      Clint
)
Average_score = Clint[
    "Client_Satisfaction_Score"
    ].mean()
print(
    "The Average score is:",
    Average_score
)
# Out:
# The client satisfaction score:
#         Firm_Name  Client_Satisfaction_Score
# 0       Deloitte                         30
# 1            PwC                         25
# 2  Ernst & Young                         23
# 3           KPMG                         22
# The Average score is: 25.0

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 5.	Total Compliance Violations by Firm. 
Compliance = (df
        ["Firm_Name"]
        .value_counts()
        .reset_index()
)
Compliance.columns = [
    "Firm_Name",
    "Compliance_Violations"
]
print(
    "The Total Compliance Violations by Firm\n:",
    Compliance
)
# Out:
# The Total Compliance Violations by Firm
# :        Firm_Name  Compliance_Violations
# 0       Deloitte                     30
# 1            PwC                     25
# 2  Ernst & Young                     23
# 3           KPMG                     22

# %%
df["Compliance_Violations"].unique()
# Out:
# array([123,  30, 124,  55,  99,  10, 114, 152,  53, 144, 186, 125,  48,
#         17,  82,  81,  87, 181,  65, 184, 183, 179,  49, 146, 169,  94,
#        136,  73,  37,  61, 166,  42, 100, 134, 138, 115, 116, 155, 193,
#        196, 139,  86, 137, 126, 149,  74,  45, 167,  20,  92, 185, 151,
#        198, 141,  25, 142,  31, 102, 103,  15,  71,  38,  58,  47,  19,
#         67, 132, 200, 121,  90, 158,  36,  39,  35, 173,  46, 153, 199])

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 6.	Total Fraud Cases Detected by Firm. 
Fraud = (
    df["Firm_Name"]
        .value_counts()
        .reset_index()
)
Fraud.columns = [
    "Firm_Name",
    "Fraud_Cases_Detected"
    ]
print("The fraud cases detected:\n")
print(Fraud)
# Out:
# The fraud cases detected:
#
#        Firm_Name  Fraud_Cases_Detected
# 0       Deloitte                    30
# 1            PwC                    25
# 2  Ernst & Young                    23
# 3           KPMG                    22

# %%
df
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
# 7.	Firm with the Highest Revenue Impact. 
Revenue = (
    df.groupby("Firm_Name")["Total_Revenue_Impact"]
    .sum()
    .reset_index()
    .head(1)
)
Revenue.columns = [
    "Firm_Name",
    "Total_Revenue_Impact"
]
print(Revenue)
# Out:
#   Firm_Name  Total_Revenue_Impact
# 0  Deloitte               8547.44

# %%
# 8.	Firm with the Lowest Revenue Impact.
Revenue = (
    df.groupby
        ("Firm_Name")
        ["Total_Revenue_Impact"]
        .sum()
        .value_counts()
        .tail(1)
)
Revenue.columns = [
    "Firm_Name",
    "Total_Revenue_Impact"
]
print("The Firm with lowest revenue impact is:\n",Revenue)
# Out:
# The Firm with lowest revenue impact is:
#  Total_Revenue_Impact
# 6108.49    1
# Name: count, dtype: int64

# %%
Revenue = (
    df.groupby("Firm_Name")["Total_Revenue_Impact"]
    .sum()
    .reset_index()
)
Revenue.columns = [
    "Firm_Name",
    "Total_Revenue_Impact"
]
print(Revenue)
# Out:
#        Firm_Name  Total_Revenue_Impact
# 0       Deloitte               8547.44
# 1  Ernst & Young               6862.86
# 2           KPMG               5735.11
# 3            PwC               6108.49

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Part 6: Industry Analysis
# 1.	Total Revenue Impact by Industry. 
Industry = (df.groupby
    ("Industry_Affected")
    ["Total_Revenue_Impact"]
    .sum()
    .reset_index()
           )
Industry.columns = [
    "Industry_Affected",
    "Total_Revenue_Impact"
]
print(Industry)
# Out:
#   Industry_Affected  Total_Revenue_Impact
# 0           Finance               5940.20
# 1        Healthcare               5475.59
# 2            Retail               8696.30
# 3              Tech               7141.81

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 2.	Total Audit Engagements by Industry.
Audit = (df.groupby
    ("Industry_Affected")
    ["Total_Audit_Engagements"]
    .sum()
    .reset_index()
        )
Audit.columns = [
    "Industry_Affected",
    "Total_Audit_Engagements"
]
print(Audit)
# Out:
#   Industry_Affected  Total_Audit_Engagements
# 0           Finance                    60681
# 1        Healthcare                    68004
# 2            Retail                    69698
# 3              Tech                    80069

# %%
# 3.	Average Audit Effectiveness Score by Industry. 
Average_Audit = (df.groupby
    ("Industry_Affected")
    ["Audit_Effectiveness_Score"]
    .mean()
    .reset_index()
                )
Average_Audit.columns = ["Industry_Affected","Audit_Effectiveness_Score"]
print(Average_Audit)
# Out:
#   Industry_Affected  Audit_Effectiveness_Score
# 0           Finance                   7.640000
# 1        Healthcare                   7.425000
# 2            Retail                   7.596296
# 3              Tech                   7.341379

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 4.	Average Client Satisfaction Score by Industry. 
Average_Client = (df.groupby
    ("Industry_Affected")
    ["Client_Satisfaction_Score"]
    .mean()
    .reset_index()
                 )
Average_Client.columns = [
    "Industry_Affected",
    "Client_Satisfaction_Score"
]
print(Average_Client)
# Out:
#   Industry_Affected  Client_Satisfaction_Score
# 0           Finance                   7.065000
# 1        Healthcare                   7.633333
# 2            Retail                   7.448148
# 3              Tech                   7.182759

# %%
# 5.	Total Fraud Cases by Industry. 
Total_fraud = (
    df.groupby
        ("Industry_Affected")
        ["Fraud_Cases_Detected"]
        .sum()
        .reset_index()
)
Total_fraud.columns = ["Industry_Affected","Fraud_Cases_Detected"]
print(Total_fraud)
# Out:
#   Industry_Affected  Fraud_Cases_Detected
# 0           Finance                  1101
# 1        Healthcare                  1410
# 2            Retail                  1365
# 3              Tech                  1394

# %%
# 6.	Industry with the Highest Revenue Impact. 
Industry_H_Revenue = (
    df.groupby
        ("Industry_Affected")
        ["Total_Revenue_Impact"]
        .sum()
        .reset_index()
        .sort_values(by="Total_Revenue_Impact", ascending=False)
        .head(1)
)
Industry_H_Revenue.columns = [
    "Industry_Affected",
    "Total_Revenue_Impact"
]
print(Industry_H_Revenue)
# Out:
#   Industry_Affected  Total_Revenue_Impact
# 2            Retail                8696.3

# %%
# 6.	Industry with the Highest Revenue Impact. 
Industry_H_Revenue = (
    df.groupby
        ("Industry_Affected")
        ["Total_Revenue_Impact"]
        .sum()
        .reset_index()
        .sort_values(by="Total_Revenue_Impact", ascending=False)
        .head(1)
)
print(Industry_H_Revenue)
# Out:
#   Industry_Affected  Total_Revenue_Impact
# 2            Retail                8696.3

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 7.	Industry with Lowest Revenue Impact. 
Industry_L_Revenue = (
    df.groupby
        ("Industry_Affected")
        ["Total_Revenue_Impact"]
        .sum()
        .reset_index()
        .sort_values(by="Total_Revenue_Impact",ascending = False) 
        .tail(1)
)
print(Industry_L_Revenue)
# Out:
#   Industry_Affected  Total_Revenue_Impact
# 1        Healthcare               5475.59

# %%
Industry_L_Revenue = (
    df.groupby
        ("Industry_Affected")
        ["Total_Revenue_Impact"]
        .sum()
        .reset_index()
        .sort_values(by="Total_Revenue_Impact",ascending = False) 
)
print(Industry_L_Revenue)
# Out:
#   Industry_Affected  Total_Revenue_Impact
# 2            Retail               8696.30
# 3              Tech               7141.81
# 0           Finance               5940.20
# 1        Healthcare               5475.59

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Part 7: AI Usage Analysis
# 1.	Total Audit Engagements by AI Usage. 
Total_Audit_AI = (
    df.groupby
        ("AI_Used_for_Auditing")
        ["Total_Audit_Engagements"]
        .sum()
        .reset_index()
)
print(Total_Audit_AI)
# Out:
#   AI_Used_for_Auditing  Total_Audit_Engagements
# 0                   No                   152539
# 1                  Yes                   125913

# %%
# 2.	Total Revenue Impact by AI Usage. 
Total_Revenue_AI = (df
    [df
        ["AI_Used_for_Auditing"]=='Yes']
    .groupby("AI_Used_for_Auditing")
        ["Total_Revenue_Impact"]
        .sum()
        .reset_index()
)
(df[df["AI_Used_for_Auditing"]=='Yes'])
print(Total_Revenue_AI)
# Out:
#   AI_Used_for_Auditing  Total_Revenue_Impact
# 0                  Yes              11139.77

# %%
# 3.	Average Audit Effectiveness Score by AI Usage. 
Average_Audit_Effectiveness = (
    df[
        df["AI_Used_for_Auditing"]=='Yes']
        .groupby
        ("AI_Used_for_Auditing")
        ["Audit_Effectiveness_Score"]
        .mean()
        .reset_index()
)

print(Average_Audit_Effectiveness)
# Out:
#   AI_Used_for_Auditing  Audit_Effectiveness_Score
# 0                  Yes                   7.595556

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 4.	Average Client Satisfaction Score by AI Usage. 
Average_Client_Satisfaction_Score_AI = (df
    [df
        ["AI_Used_for_Auditing"]=='Yes']
    .groupby
    ("AI_Used_for_Auditing")
    ["Client_Satisfaction_Score"]
    .mean()
    .reset_index()
                                    )
print(Average_Client_Satisfaction_Score_AI)
# Out:
#   AI_Used_for_Auditing  Client_Satisfaction_Score
# 0                  Yes                   7.366667

# %%
# 5.	Average Fraud Detection by AI Usage. 
Average_Fraud_Detection_AI =(df
    [
    df
    ["AI_Used_for_Auditing"]=='Yes']
    .groupby
        ("AI_Used_for_Auditing")
        ["Fraud_Cases_Detected"]
        .mean()
        .reset_index()
)
print(Average_Fraud_Detection_AI)
# Out:
#   AI_Used_for_Auditing  Fraud_Cases_Detected
# 0                  Yes             50.222222

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 6.	Compare AI vs non-AI performance. 
Compare_AI_Non_AI_performance =(
    df.groupby
    ("AI_Used_for_Auditing")
    ["Total_Audit_Engagements"]
    .sum()
    .reset_index()
                                )
print(Compare_AI_Non_AI_performance)
# Out:
#   AI_Used_for_Auditing  Total_Audit_Engagements
# 0                   No                   152539
# 1                  Yes                   125913

# %%
# Part 8: Compliance & Fraud Analysis
# 1.	Total Compliance Violations by Firm.
Firm = (df.groupby
    ("Firm_Name")
    ["Compliance_Violations"]
    .sum()
    .reset_index()
       )
print(Firm)
# Out:
#        Firm_Name  Compliance_Violations
# 0       Deloitte                   3127
# 1  Ernst & Young                   2724
# 2           KPMG                   2070
# 3            PwC                   2627

# %%
# 2.	Total Fraud Cases by Firm.
Fraud = (df.groupby
    ("Firm_Name")
    ["Fraud_Cases_Detected"]
    .sum()
    .reset_index()
        )
print(Fraud)
# Out:
#        Firm_Name  Fraud_Cases_Detected
# 0       Deloitte                  1481
# 1  Ernst & Young                  1031
# 2           KPMG                  1319
# 3            PwC                  1439

# %%
Fraud = (df.groupby
    ("Firm_Name")
    ["Fraud_Detection_Rate"]
    .sum()
    .reset_index()
        )
print(Fraud)
# Out:
#        Firm_Name  Fraud_Detection_Rate
# 0       Deloitte              6.338566
# 1  Ernst & Young              5.335715
# 2           KPMG              5.564517
# 3            PwC              9.321692

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 3.Average Compliance Violations by Industry. 
Industy = (
    df.groupby
        ("Industry_Affected")
        ["Compliance_Violations"]
        .mean()
        .sort_values(ascending = False)
        .reset_index()
)
print(Industy)
# Out:
#   Industry_Affected  Compliance_Violations
# 0            Retail             119.481481
# 1        Healthcare             111.041667
# 2              Tech             103.034483
# 3           Finance              83.450000

# %%
# 4.	Highest Fraud Detection Firm. 
Highest = (df
    .groupby
    ("Firm_Name")
    ["Fraud_Cases_Detected"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
    .head(1)
          )
print(Highest)
# Out:
#   Firm_Name  Fraud_Cases_Detected
# 0  Deloitte                  1481

# %%
# 5.	Lowest Fraud Detection Firm.
Lowest = (
    df.groupby
        ("Firm_Name")
        ["Fraud_Cases_Detected"]
        .sum()
        .sort_values(ascending=True)
        .reset_index()
        .head(1)
)
Lowest.columns = ["Firm_Name","Fraud_Cases_Detected"]
print("The lowest value firm is:\n",Lowest)
# Out:
# The lowest value firm is:
#         Firm_Name  Fraud_Cases_Detected
# 0  Ernst & Young                  1031

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 6.	Firm with Maximum Compliance Violations. 
Maximum = (df.groupby("Firm_Name")["Compliance_Violations"].max().sort_values(ascending=False).reset_index().head(1))
print(Maximum)
# Out:
#   Firm_Name  Compliance_Violations
# 0  Deloitte                    200

# %%
# 7.	Industry with the Highest Compliance Violations. 
Highest = (
    df
        .groupby
        ("Industry_Affected")
        ["Compliance_Violations"]
        .sum()
        .sort_values(ascending=False)
        .reset_index()
        .head(1)
)
print(Highest)
# Out:
#   Industry_Affected  Compliance_Violations
# 0            Retail                   3226

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Part 9: Year Analysis
# 1.	Total Revenue Impact by Year.
Impact = (df.groupby("Year")["Total_Revenue_Impact"].sum().reset_index())
print(Impact)
# Out:
#    Year  Total_Revenue_Impact
# 0  2020               4509.59
# 1  2021               6094.55
# 2  2022               3325.64
# 3  2023               3325.98
# 4  2024               4629.88
# 5  2025               5368.26

# %%
# 2.	Total Audit Engagements by Year. 
Engagements =(df.groupby("Year")["Total_Audit_Engagements"].sum().reset_index())
print(Engagements)
# Out:
#    Year  Total_Audit_Engagements
# 0  2020                    55139
# 1  2021                    51888
# 2  2022                    43667
# 3  2023                    35752
# 4  2024                    43753
# 5  2025                    48253

# %%
# 3.	Total Fraud Cases by Year. 
Cases = (df.groupby("Year")["Fraud_Cases_Detected"].sum().reset_index())
print(Cases)
# Out:
#    Year  Fraud_Cases_Detected
# 0  2020                  1042
# 1  2021                   963
# 2  2022                   667
# 3  2023                   727
# 4  2024                   938
# 5  2025                   933

# %%
# 4.	Total Compliance Violations by Year. 
Compliance = (df.groupby("Year")["Compliance_Violations"].sum().reset_index())
print(Compliance)
# Out:
#    Year  Compliance_Violations
# 0  2020                   2441
# 1  2021                   1562
# 2  2022                   1556
# 3  2023                   1454
# 4  2024                   1529
# 5  2025                   2006

# %%
# 5.	Average Audit Effectiveness by Year. 
Effectiveness = (df.groupby("Year")["Audit_Effectiveness_Score"].mean().reset_index())
print(Effectiveness)
# Out:
#    Year  Audit_Effectiveness_Score
# 0  2020                   7.585714
# 1  2021                   6.921053
# 2  2022                   7.533333
# 3  2023                   7.676923
# 4  2024                   7.712500
# 5  2025                   7.625000

# %%
# 6.	Average Client Satisfaction by Year. 
Satisfaction = (df.groupby("Year")["Client_Satisfaction_Score"].mean().reset_index())
print(Satisfaction)
# Out:
#    Year  Client_Satisfaction_Score
# 0  2020                   7.647619
# 1  2021                   7.268421
# 2  2022                   6.766667
# 3  2023                   7.423077
# 4  2024                   7.387500
# 5  2025                   7.437500

# %%
# 7.	Year with Highest Revenue Impact. 
Highest = (df.groupby("Year")["Total_Revenue_Impact"].sum().sort_values(ascending=False).reset_index().head(1))
print(Highest)
# Out:
#    Year  Total_Revenue_Impact
# 0  2021               6094.55

# %%
# 8.	Year with Lowest Revenue Impact.
Highest = (df.groupby("Year")["Total_Revenue_Impact"].sum().sort_values(ascending=True).reset_index().head(1))
print(Highest)
# Out:
#    Year  Total_Revenue_Impact
# 0  2022               3325.64

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Part 10: Top & Bottom Analysis
# 1.	Top 10 Records by Revenue Impact. 
df.sort_values(by = "Total_Revenue_Impact").tail(10)
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 9   2021  Ernst & Young                     2490               74
# 43  2024           KPMG                     3958              442
# 6   2022       Deloitte                     1199              148
# 29  2025  Ernst & Young                     3571               86
# 93  2021       Deloitte                      797              133
# 61  2020           KPMG                     2654              231
# 53  2023  Ernst & Young                     3101              398
# 87  2025            PwC                     1771              158
# 15  2021       Deloitte                     3490              127
# 69  2021  Ernst & Young                     1069              222
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 9                     144                    22            Retail
# 43                    115                    94        Healthcare
# ...

# %%
df
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0   2020            PwC                     2829               51
# 1   2022       Deloitte                     3589              185
# 2   2020            PwC                     2438              212
# 3   2021            PwC                     2646              397
# 4   2020            PwC                     2680              216
# ..   ...            ...                      ...              ...
# 95  2022           KPMG                     4179               77
# 96  2020  Ernst & Young                     2119              112
# 97  2021       Deloitte                     3810              463
# 98  2025       Deloitte                     1896              110
# 99  2021            PwC                     4473              195
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                     123                    39        Healthcare
# ...

# %%
# 2.	Bottom 10 Records by Revenue Impact. 
df.sort_values(by="Total_Revenue_Impact").head(10)
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 36  2023            PwC                     3449              102
# 4   2020            PwC                     2680              216
# 40  2020            PwC                     3981              199
# 7   2020            PwC                     4092              500
# 89  2022       Deloitte                      962              356
# 16  2020  Ernst & Young                     3264              435
# 67  2022           KPMG                     4624              472
# 34  2022       Deloitte                     4287              158
# 80  2020       Deloitte                      912              481
# 76  2020  Ernst & Young                     1286              391
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 36                     61                    42           Finance
# 4                      99                    46        Healthcare
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 3.	Top 10 Audit Engagements. 
df.sort_values("Total_Audit_Engagements").tail(10)
# Out:
#     Year      Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 92  2022            PwC                     4595              481
# 47  2021       Deloitte                     4601               65
# 86  2025            PwC                     4606              221
# 67  2022           KPMG                     4624              472
# 28  2025  Ernst & Young                     4773              497
# 48  2025            PwC                     4775              380
# 71  2024       Deloitte                     4784              382
# 17  2022       Deloitte                     4813              249
# 94  2023  Ernst & Young                     4895              123
# 85  2020            PwC                     4946               78
#
#     Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 92                    173                    54            Retail
# 47                    196                    28              Tech
# ...

# %%
df["Firm_Name"].unique()
# Out:
# array(['PwC', 'Deloitte', 'Ernst & Young', 'KPMG'], dtype=object)

# %%
# 4.	Top 5 Firms by Revenue Impact. 
TT = (df.groupby("Firm_Name")["Total_Revenue_Impact"].sum().sort_values(ascending=False).head(5).reset_index())
print(TT)
# Out:
#        Firm_Name  Total_Revenue_Impact
# 0       Deloitte               8547.44
# 1  Ernst & Young               6862.86
# 2            PwC               6108.49
# 3           KPMG               5735.11

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 5.	Top 5 Industries by Revenue Impact. 
II = (df.groupby("Industry_Affected")["Total_Revenue_Impact"].sum().sort_values(ascending=False).reset_index().head(5))
print(II)
# Out:
#   Industry_Affected  Total_Revenue_Impact
# 0            Retail               8696.30
# 1              Tech               7141.81
# 2           Finance               5940.20
# 3        Healthcare               5475.59

# %%
# 6.	Bottom 5 Firms by Audit Effectiveness Score. 
FF = (df.groupby("Firm_Name")["Audit_Effectiveness_Score"].sum().sort_values(ascending = False).reset_index().tail())
print(FF)
# Out:
#        Firm_Name  Audit_Effectiveness_Score
# 0       Deloitte                      225.6
# 1            PwC                      184.8
# 2  Ernst & Young                      171.5
# 3           KPMG                      167.1

# %%
# 7.	Top 5 Firms by Client Satisfaction Score. 
SS = (df.groupby("Firm_Name")["Client_Satisfaction_Score"].sum().sort_values(ascending = False).reset_index().head(5))
print(SS)
# Out:
#        Firm_Name  Client_Satisfaction_Score
# 0       Deloitte                      228.7
# 1            PwC                      180.4
# 2  Ernst & Young                      170.0
# 3           KPMG                      154.8

# %%
# Part 11: Correlation Analysis
# 1.	Correlation between Employee Workload and Audit Effectiveness. 
correlation = df["Employee_Workload"].corr(df["Audit_Effectiveness_Score"])

print("Correlation between Employee Workload and Audit Effectiveness:")
print(correlation)
# Out:
# Correlation between Employee Workload and Audit Effectiveness:
# -0.07069001847242817

# %%
D = df["Employee_Workload"].corr(df["Audit_Effectiveness_Score"])
print(D)
# Out:
# -0.07069001847242817

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 2.	Correlation between High-Risk Cases and Fraud Cases. 
G = df["High_Risk_Cases"].corr(df["Fraud_Cases_Detected"])
print(D)
# Out:
# -0.07069001847242817

# %%
# 3.	Correlation between Revenue Impact and Audit Effectiveness. 
HH = df["Total_Revenue_Impact"].corr(df["Audit_Effectiveness_Score"])
print(HH)
# Out:
# 0.02907559853530187

# %%
# 4.	Correlation between Client Satisfaction and Audit Effectiveness. 
HH = df["Client_Satisfaction_Score"].corr(df["Audit_Effectiveness_Score"])
print(HH)
# Out:
# 0.1024107108278232

# %%
# 5.	Display Correlation Heatmap. 
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
correlation_matrix = df.select_dtypes(include="number").corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,      # Show correlation values
    cmap="coolwarm", # Color scheme
    fmt=".2f",       # Display 2 decimal places
    linewidths=0.5
)

plt.title("Correlation Heatmap")
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Part 12: Visualizations
# Bar Charts
# 1.	Revenue Impact by Firm.
TT = (df.groupby("Firm_Name")["Total_Revenue_Impact"].sum().sort_values(ascending = False))
plt.figure(figsize=(10, 6))
TT.plot(kind='bar')
plt.title("Revenue Impact by Firm")
plt.xlabel("Firm Name")
plt.ylabel("Total Revenue Impact")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
MM = df.groupby("Firm_Name")["Total_Revenue_Impact"].sum().sort_values(ascending=True)
plt.figure(figsize=(12,8))
MM.plot(kind='barh',edgecolor= 'black')
plt.title("Revenue Impact by Firm")
plt.ylabel("Total Revenue Impact")
plt.xlabel("Firm Name")
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 2.	Revenue Impact by Industry. 
RR = df.groupby("Industry_Affected")["Total_Revenue_Impact"].sum().sort_values(ascending = False)
plt.figure(figsize = (10,6), edgecolor = 'black')
RR.plot(kind='bar',color='teal')
plt.title("Revenue Impact by Industry",fontsize=18)
plt.ylabel("Total Revenue Impact",fontsize=14)
plt.xlabel("Industry",fontsize=14)
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# 3.	Audit Engagements by Firm. 
AA = df.groupby("Firm_Name")["Total_Audit_Engagements"].sum().sort_values(ascending=False)
plt.figure(figsize=(10,6),edgecolor='black')
AA.plot(kind='bar',color='pink')
plt.title("Audit Engagements by Firm", fontsize= 18, color = 'blue')
plt.ylabel("Total Audit Engagements",color ='blue', fontsize = 14)
plt.xlabel("Firm Name", color = 'blue', fontsize = 14)
plt.grid(axis = "y", linestyle= "--",alpha = 0.5)
plt.tight_layout()
plt.xticks(rotation = 45)
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 4.	Compliance Violations by Firm. 
HH = (df.groupby("Firm_Name")["Compliance_Violations"].sum().sort_values(ascending=False))
plt.figure(figsize = (12,6),edgecolor='black')
HH.plot(kind = 'bar', color ='blue')
plt.title("Compliance Violations by Firm. ", fontsize= 18, color = "red")
plt.ylabel("Compliance Violations",fontsize = 16)
plt.xlabel("Name",fontsize = 16)
plt.xticks(rotation = 45)
plt.grid(axis = "y", linestyle='--',alpha = 0.5)
plt.tight_layout()
plt.show()

# %%
AA = df.groupby("Firm_Name")["Total_Audit_Engagements"].sum().sort_values(ascending=False)
plt.figure(figsize=(10,6),edgecolor='black')
AA.plot(kind='bar',color='pink')
plt.title("Audit Engagements by Firm", fontsize= 18, color = 'blue')
plt.ylabel("Total Audit Engagements",color ='blue', fontsize = 14)
plt.xlabel("Firm Name", color = 'blue', fontsize = 14)
plt.grid(axis = "y", linestyle= "--",alpha = 0.5)
plt.tight_layout()
plt.xticks(rotation = 45)
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
df["Total_Revenue_Impact"].sort_values(ascending = False).head(10)
# Out:
# 69    497.06
# 15    495.19
# 87    485.64
# 53    483.07
# 61    478.00
# 93    474.32
# 29    474.21
# 6     468.82
# 43    468.13
# 9     461.33
# Name: Total_Revenue_Impact, dtype: float64

# %%
# 1.	Top 10 Revenue Impact Records. 
TT = df["Total_Revenue_Impact"].sort_values(ascending= False).head(10)
plt.figure(figsize= (18,9),edgecolor = 'black')
TT.plot(kind='barh',color = 'blue')
plt.title("Top 10 Revenue Impact Records")
plt.ylabel("Number")
plt.xlabel("Revenue impact")
plt.grid( axis ='x', linestyle ="--", alpha = 0.5)
plt.tight_layout()
plt.xticks(rotation = 45)
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 2.	Top 10 Audit Engagement Records. 
KK = df["Total_Audit_Engagements"].sort_values(ascending= False).head(10)
plt.figure(figsize=(12,6),edgecolor="black")
KK.plot(kind='barh',color='blue')
plt.title("Top 10 Audit Engagement Records",fontsize=18)
plt.ylabel(" Engagement Sl_No",fontsize=14)
plt.xlabel("Total Audit Engagements",fontsize = 14)
plt.grid(axis = 'x', linestyle ='--', alpha = 0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# Pie Charts
# 1.	Firm-wise Revenue Contribution.
DD = df.groupby("Firm_Name")["Total_Revenue_Impact"].sum()
plt.figure(figsize=(5,5))
plt.pie(DD, labels =DD.index,
        autopct="%1.1f%%",      # Show percentages
        explode=[0] * len(DD) ) # Slightly separate all slices
plt.title("Firm-wise Revenue Contribution")
plt.show()

# %%
# 2.	AI Usage Distribution. 
AA = df["AI_Used_for_Auditing"].value_counts()
plt.figure(figsize = (5,5))
plt.pie(AA, labels=AA.index,
        autopct = "%1.1f%%",
        explode =[0]*len(AA))
plt.title("AI Usage Distribution")
plt.show()

# %%
AA = df.groupby("Firm_Name")["AI_Used_for_Auditing"].value_counts()
plt.figure(figsize = (5,5))
plt.pie(AA, labels=AA.index,
        autopct = "%1.1f%%",
        explode =[0]*len(AA))
plt.title("AI Usage Distribution")
plt.show()

# %%
AA = df.groupby("Firm_Name")["AI_Used_for_Auditing"].value_counts()
colors = ["green" if status == "Yes" else "red" for _, status in AA.index]
plt.figure(figsize = (5,5))
plt.pie(AA, labels=AA.index,
        colors=colors,
        autopct = "%1.1f%%",
        
        explode =[0.10]*len(AA))
plt.title("AI Usage Distribution")
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score',
#        'Revenue Impact (Millions)', 'Risk Ratio', 'Compliance_Rate',
#        'Fraud_Detection_Rate'],
#       dtype='object')

# %%
# 3.	Industry-wise Revenue Contribution. 
II = df.groupby("Industry_Affected")["Total_Revenue_Impact"].sum()
plt.figure(figsize = (5,5))
plt.pie(II, labels = II.index,
        autopct = "%1.1f%%",
        explode = [0.10]*len(II))
plt.title("Industry-wise Revenue Contribution",fontsize=18,color = 'black',fontweight="bold")
plt.show()

# %%
II = df.groupby("Industry_Affected")["Total_Revenue_Impact"].sum()
plt.figure(figsize = (5,5))
plt.pie(II,  labels = II, autopct = "%1.1f%%", explode = (0.05)* len[II]
plt.title("Industry-wise Revenue Contribution",fontsize=18,color = 'black',fontweight="bold")
plt.show()
# Out:
#   Cell In[169], line 3
#     plt.pie(II,  labels = II, autopct = "%1.1f%%", explode = (0.05)* len[II]
#            ^
# SyntaxError: '(' was never closed

# %%
df.columns

# %%
# Histograms
# 1.	Distribution of Revenue Impact.
plt.figure(figsize = (8,5))
plt.hist(df["Total_Revenue_Impact"], bins=10,edgecolor = 'black')
plt.title("Distribution of Revenue Impact", color = 'black',fontweight = 'bold', fontsize = 18)
plt.xlabel("Revenue Impact",color = 'black',fontweight = 'bold', fontsize = 12)
plt.ylabel("Frequency",color = 'black',fontweight = 'bold', fontsize = 12)
plt.grid( axis = 'y', linestyle = '--')
plt.show()

# %%
# 2.	Distribution of Audit Effectiveness Score.
plt.figure(figsize = (10,5),edgecolor = 'black')
plt.hist(df["Audit_Effectiveness_Score"], bins = 10, edgecolor = 'black')
plt.title("Distribution of Audit Effectiveness Score", fontweight = 'bold', fontsize= 18)
plt.xlabel("Effectiveness Score", fontweight = 'bold', fontsize= 14)
plt.ylabel("Frequency", fontweight = 'bold', fontsize= 14)
plt.grid( axis = 'y',linestyle ='--')
plt.show()

# %%
df.columns

# %%
# 3.	Distribution of Client Satisfaction Score. 
plt.figure(figsize = (12,5),edgecolor = 'black')
plt.hist(df["Client_Satisfaction_Score"],bins= 10, edgecolor = 'black')
plt.title("Distribution of Client Satisfaction Score", color='black', fontsize = 18, fontweight = 'bold')
plt.ylabel("Frequency",color='black', fontsize = 14, fontweight = 'bold')
plt.xlabel("Satisfaction Score",color='black', fontsize = 14, fontweight = 'bold')
plt.grid(axis = 'y', linestyle ='--')
plt.show()

# %%
# Scatter Plots
# 1.	Employee Workload vs Audit Effectiveness.
plt.figure(figsize=(10,5))
plt.scatter(df["Employee_Workload"], df["Audit_Effectiveness_Score"],color = 'blue',alpha = 0.7)
plt.title("Employee Workload vs Audit Effectiveness", color = 'black', fontsize = 18, fontweight = 'bold')
plt.ylabel("Employee Workload",color = 'black', fontsize = 1, fontweight = 'bold')
plt.xlabel("Audit Effectiveness",color = 'black', fontsize = 1, fontweight = 'bold')
plt.grid(True)
plt.show()

# %%
df.columns

# %%
# 2.	Revenue Impact vs Client Satisfaction. 
plt.figure(figsize=(12,5),edgecolor = 'black')
plt.scatter( df["Total_Revenue_Impact"], df["Client_Satisfaction_Score"])
plt.title("Revenue Impact vs Client Satisfaction", fontsize = 18, fontweight = 'bold')
plt.ylabel("Revenue Impact",fontsize = 14, fontweight = 'bold')
plt.xlabel("Client Satisfaction",fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.show()

# %%
# 3.	High Risk Cases vs Fraud Cases
plt.figure(figsize=(12,5), edgecolor = 'black')
plt.scatter( df["High_Risk_Cases"], df["Fraud_Cases_Detected"])
plt.title("High Risk Cases vs Fraud Cases", fontsize = 18, fontweight = 'bold')
plt.ylabel("High Risk Cases", fontsize = 14, fontweight = 'bold')
plt.xlabel("Fraud Cases", fontsize=14,fontweight = 'bold')
plt.grid(True)
plt.show()

# %%
df.columns

# %%
# 1.	Year-wise Revenue Impact Trend
YY = df.groupby("Year")["Total_Revenue_Impact"].sum().reset_index()
plt.figure(figsize=(8,5))
plt.plot(YY, linestyle="--",color ='b',marker='D')
plt.title("ghgch")
plt.show()

# %%
Day =df.loc[:200, "Year"]
Revenue = df.loc[:200,"Total_Revenue_Impact"]
plt.figure(figsize=(20,10),dpi=100)
plt.plot(Day,Revenue,linestyle='--',color ='b',marker='D')
plt.title("Daily Revenue Trend")
plt.ylabel("Revenue")
plt.xlabel("Day")
plt.show()

# %%
yearly_revenue = df.groupby("Year")["Total_Revenue_Impact"].sum()
plt.figure(figsize=(15,5))
plt.plot(
    yearly_revenue.index,
    yearly_revenue.values,
    marker='o',
    linestyle='--',
    linewidth=2,
    color='blue'
)

plt.title("Year-wise Revenue Impact Trend", fontsize=14, fontweight='bold')
plt.xlabel("Year", fontsize=12, fontweight='bold')
plt.ylabel("Total Revenue Impact", fontsize=12, fontweight='bold')
plt.xticks(yearly_revenue.index)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
df.columns

# %%
# 2.	Year-wise Audit Engagement Trend. 
Yearly = df.groupby("Year")["Total_Audit_Engagements"].sum()
plt.figure(figsize = (15,6))
plt.plot( Yearly.index,
          Yearly.values,
          marker = "o",
          linestyle ="--")
plt.title("Year-wise Audit Engagement Trend", fontsize = 18, fontweight ='bold')
plt.ylabel("Total_Audit_Engagements",fontsize = 18, fontweight ='bold')
plt.xlabel("Year",fontsize = 18, fontweight ='bold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# 3.	Year-wise Fraud Detection Trend. 
NN = df.groupby("Year")["Fraud_Cases_Detected"].sum()
plt.figure(figsize = (15,6))
plt.plot( NN.index,
          NN.values,
          marker = "o",
          linestyle = "--")
plt.title("Year-wise Fraud Detection Trend", fontsize = 18, fontweight ='bold')
plt.ylabel("Fraud Detection Trend",fontsize = 18, fontweight ='bold')
plt.xlabel("Year",fontsize = 18, fontweight ='bold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# 4.	Year-wise Compliance Violations Trend.
BB = df.groupby("Year")["Compliance_Violations"].sum()
plt.figure(figsize = (15,6))
plt.plot( BB.index,
          BB.values,
          linestyle = "--",
          marker = "o")
plt.title("Year-wise Compliance Violations Trend", fontsize = 18, fontweight ='bold')
plt.ylabel("Complex",fontsize = 18, fontweight ='bold')
plt.xlabel("Year",fontsize = 18, fontweight ='bold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
